# %% [markdown]
# Luke Gontier, Thibaut Lahaie, Nathan Reboul, Marion Valls
#
# # Dossier de recherche : Jeu des gendarmes et des voleurs
#
# ## I. Contexte :
#
# C’est durant les années 80 que ce jeu a fait son apparition. Depuis, ses nombreuses variantes sont étudiées. Le jeu des gendarmes et des voleurs fut lui-même premier variant des graphes réflexifs (graphes dont tous les sommets ont une boucle). C’est indépendamment que le duo NOWAKOWSKI & WINKLER et QUILLOT ont publié le concept. Les deux travaux partent du principe qu’il n’y a qu’un seul gendarme et un voleur. Suite à cela, beaucoup d’algorithme gendarmes gagnant ont été rédigés. Bien que ce principe de criminel et force de l’ordre s’approche d’un concept réel semblable à une poursuite pour sécuriser un environnement, il y a depuis quelques années un milieu virtuel où son utilisation est récurrente et variée : le Web.
#
#
#
# ## II. Présentation générale du jeu :
#
# Le jeu des gendarmes et des voleurs est un jeu stratégique dans lequel deux joueurs s’affrontent sur un plateau. Chacun des joueurs représente soit le camp des gendarmes ou des voleurs et leur objectif diffère en fonction du camp.
# Le joueur dans le camp des gendarmes dispose de plusieurs pions rouges qu’il peut déplacer sur le plateau un a un. Son objectif est de réussir à placer un pion rouge sur une même case qu’un pion voleur (noir) afin de remporter la partie.
#
# Le joueur dans le camp des voleurs dispose donc d’un ou de plusieurs pions noirs en fonction des règles définie, il doit lui aussi les déplacer un a un et son objectif est de ne jamais permettre à un gendarme de placer un pion rouge sur une même case qu’un pion noire.
#
# Ce jeu possède une grande variété de règles notamment concernant la taille et la forme du plateau, mais aussi en fonction du nombre de pion donné à chaque joueur.
#
#
#
# ## III. Règles du jeu :
#
# * Pour les Gendarmes :
#
#     - Objectif du Jeu : Attraper le ou les pions du voleur en occupant la même case.
#
#
#
# * Pour les Voleurs :
#
#      - Objectif du Jeu : Éviter le ou les pions des gendarmes et ne pas se retrouver sur la même case.
#
#
#
# * Règlement :
#
#     1. Le camp des gendarmes place ses pions en premier sur le plateau, où il le souhaite.
#
#     2. Ensuite, le camp des voleurs positionne ses pions sur le plateau, également à leur convenance.
#
#     3. Chaque camp peut déplacer un seul pion d'une case dans n'importe quelle direction (droite, gauche, haut, bas, etc.).
#
#     4. Le camp des gendarmes commence en premier.
#
#     5. Le jeu se termine lorsque les pions des gendarmes capturent tous les pions des voleurs ou que le nombre de déplacement total est atteint.
#
#
#
# ## IV. Les variantes du jeu
#
# * Vitesse : Dans les règles, le voleur et le gendarme ont une vitesse de déplacement de 1 par tour. On peut imaginer que le voleur peut être plus lent ou plus rapide pour changer l’issue du jeu.
#
#
#
# * Nombre : Le nombre de gendarmes et de voleurs dans une partie peut varier et peut influencer directement l’issue du jeu.
#
#
#
# * Plateau : La forme et la taille du plateau peuvent varier : il peut être plus ou moins grand, autorisant ou non les déplacements en diagonale et sur place.
#
#
#
# ## V. Graphes :
#
# Afin de déterminer les possibilités de victoire existantes du jeu pour les deux camps, nous allons utiliser la [théorie des graphes](https://fr.wikipedia.org/wiki/Th%C3%A9orie_des_graphes).
#
# Les notions de graphes que nous allons utiliser nous permettent d’explorer les différentes possibilités proposées aux joueurs. En suivant les graphes nous seront donc capables de déterminer si un graphe est gendarme-gagnant ou voleur-gagnant.
#
#
#
# 1. Définition :
#
# Pour bien comprendre le sujet il est important de définir quelques termes.
#
# - Graphe : Une représentation abstraite d'un ensemble de sommets reliés entre eux, où certaines paires sont liées par des relations.
#
# - Arrête : Une liaison ou connexion entre deux sommets dans un graphe, représentant souvent une relation ou une interaction entre les sommets correspondants.
#
# - Arc : Une arête orientée, indiquant une direction spécifique entre deux sommets. Les arcs ont un point de départ et un point d'arrivée.
#
# - Sommet : Un point individuel dans un graphe, représentant un objet ou une entité. Aussi appelé nœud.
#
# - Cycle : Une séquence d'arêtes dans un graphe qui forme un chemin fermé, c'est-à-dire qu'il commence et se termine au même sommet.
#
# - Chemin : Une séquence d'arêtes (ou d'arcs) dans un graphe, reliant une séquence de sommets sans nécessairement former un cycle. Un chemin peut être orienté ou non orienté.
#
# - Graphe réflexif : Si chaque sommet du graphe est lié à lui-même par une arête.
#
# - Boucle : Une arête qui relie un sommet à lui-même est une boucle.
#
# 2. Gagner en utilisant les graphes :
#
# Les graphes sont souvent utilisés afin de mieux appréhender les jeux combinatoires. En effet, leur usage permet de modéliser les différents choix réalisables dans un jeu et de les analyser.
#
# Les sommets représentent une position dans un jeu tandis que les arcs les reliant sont les choix réalisés par les joueurs.
#
# En étudiants un graphe, il est possible de repérer les différentes possibilités permettant à un joueur de s’assurer la victoire.
#
# 3. Première approche :
#
# Prenons l’exemple du jeu dans lequel le gendarme et le voleur ne disposent que d’un seul pion :
#
# Il est possible dans ce cas de déterminer si la victoire est possible pour un gendarme en déterminant si le graphe est dit “[cop-win](https://fr.wikipedia.org/wiki/Graphe_cop-win)”.
# On dit alors qu’aucune solution ne permet au gendarme de remporter une partie lorsque le graphe est dit “robber-win”.
#
# Un graphe est cop-win lorsqu’il est démontable fini, c’est à dire que les différents sommets qui composent le graphe peuvent être démantelés par récurrence.
# On dit qu’un sommet v est dominé par un sommet w si l’ensemble des sommets adjacents au sommet v sont inclus parmi les sommets adjacents au sommet w.
#
# Lorsqu’un graphe est cyclique, il est robber-win, et lorsqu’il n'est composé que d’un sommet, il est cop-win
#
# Afin de prouver que le graphe est cop-win, nous allons retirer d’un graphe chacun de ses sommets étant dominés par un autre par récurrence.
#
# | Graphe initial | Graphe sans sommet dominé | Bilan |
# | :------------: | :-----------------------: | :---: |
# | ![graphe initial](media/graphe_initial.png) | ![graphe sans sommet dominé](media/graphe_sans_sommet.png) | Après avoir retiré par récurrence l’ensemble des sommets dominés. On obtient un graphe composé d’un seul point. \n Cela veut donc dire que le graphe initial est cop-win |
# | ![graphe initial](media/graphe_initial_2.png) | ![graphe sans sommet dominé](media/graphe_sans_sommet_2.png) | Après avoir retiré par récurrence l’ensemble des sommets dominés. On obtient un graphe composé d’un seul point. \n  veut donc dire que le graphe initial est cop-win |
# | ![graphe initial](media/graphe_initial_3.png) | ![graphe sans sommet dominé](media/graphe_sans_sommet_3.png) | Après avoir retiré par récurrence l’ensemble des sommets dominés. On obtient un graphe cyclique. \n Cela veut donc dire que le graphe initial est robber-win |
#
# Un graphe est donc cop-win s’il est complet ou que l’ensemble de ses sommets est dominé par un autre.
#
#
# 4. Étude d’un plateau de taille 2x2
#
# Dans le cadre d’une partie avec 1 gendarme et 1 voleur sur un plateau 2x2 nous avons étudions les disposions des pions sur le plateau afin de trouver les stratégies gagnantes.
#
# Graphe G, de 16 sommets
#
# <img src="media/graphe_diamant.png" width="400">
#
# <img src="media/graphe_choix.png" width="500">
#
#
# <u>Légende :<u>
#
# X : voleur
#
# O : gendarme
#
# Un numéro correspond à un sommet dans le graphe.
#
# Les sommets en fond jaune sont des cas où la partie se termine.
#
# 5. Cas particulier
#
# | Graphe | Observation | Démonstration |
# | :----: | :---------: | :-----------: |
# | ![graphe](media/graphe_isole.png) | Un graphe non connexe est voleur gagnant. | Initialement, le policier choisit un sommet du graphe. Il suffit que le voleur choisisse un sommet sur une composante connexe différente de celle conte nant le sommet occupé par le policier pour échapper éternellement à la capture.  |
# | ![graphe](media/graphe_isole.png) | Un graphe non connexe est voleur gagnant pour le jeu de poursuite irréflexif. | Donc la même démonstration que l’observation précédente reste valide. |
#
# ## VI. Stratégie
#
# Une première stratégie gagnante peut être trouvée en appliquant un algorithme élaboré par G. Hahn et G. MacGillivray.
#
# [p.46 [El_Ouarari_Amal_2006_memoire.pdf (umontreal.ca)](https://papyrus.bib.umontreal.ca/xmlui/bitstream/handle/1866/17845/El_Ouarari_Amal_2006_memoire.pdf?sequence=1&isAllowed=y) ]
# ## VII. Intelligence artificielle :
#
# L'objectif de ce projet est de créer un environnement interactif mettant en scène deux intelligences artificielles (IA) qui s'affronteront dans le rôle des gendarmes et des voleurs, chacune cherchant à remporter la partie. Au cours des différents affrontements, nous procéderons à une analyse comparative entre les graphes préalablement définis et les résultats de chaque partie.
#
#
# Nos IA seront basées sur le modèle des arbres de décision, où chaque décision est dictée par un arbre logique définissant les actions à entreprendre en fonction de la situation. Pour illustrer, lors du tour des voleurs, si un gendarme a la possibilité d'atteindre un voleur au prochain tour, le joueur examinera les cases accessibles. Si une case n'est pas occupée par un gendarme ou n'est pas à leur portée, le voleur s'y dirigera. En revanche, si la case est occupée ou hors de portée, le voleur prendra une action conduisant à une défaite inévitable.
#
#
#
#
# <u>Liens utiles :<u>
#
# * [Zine_Youssef_2005_memoire.pdf (umontreal.ca)](https://papyrus.bib.umontreal.ca/xmlui/bitstream/handle/1866/16692/Zine_Youssef_2005_memoire.pdf?sequence=1&isAllowed=y)
#
# * [El_Ouarari_Amal_2006_memoire.pdf (umontreal.ca)](https://papyrus.bib.umontreal.ca/xmlui/bitstream/handle/1866/17845/El_Ouarari_Amal_2006_memoire.pdf?sequence=1&isAllowed=y)
#
# * [Jeu des gendarmes et du voleur (inria.fr)](https://www-sop.inria.fr/mascotte/seminaires/JGA08/pdf/nisse.pdf)
#
# * [Ramanampanoharana_Tantely_2004_memoire.pdf (umontreal.ca)](https://papyrus.bib.umontreal.ca/xmlui/bitstream/handle/1866/16660/Ramanampanoharana_Tantely_2004_memoire.pdf?sequence=1&isAllowed=y)
#
# * [Jeux de poursuite policier-voleur sur un graphe - Université de Laval](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&ved=2ahUKEwjRgej70e2BAxVwTaQEHSTvDcsQFnoECBMQAQ&url=https%3A%2F%2Fdam-oclc.bac-lac.gc.ca%2Fdownload%3Fis_thesis%3D1%26oclc_number%3D1276809195%26id%3Dac6f38e5-add9-4f95-a856-15aa653f7f7d%26fileName%3D30386.pdf&usg=AOvVaw3F_gmN6hew6LFjLydXOLzP&opi=89978449)
#
# <u>Anglais :<u>
#
# * [Ramamonjisoa_Frank_2022_these.pdf (umontreal.ca)](https://papyrus.bib.umontreal.ca/xmlui/bitstream/handle/1866/27810/Ramamonjisoa_Frank_2022_these.pdf?sequence=2#page=73)
#
# * [Vertex-to-vertex pursuit in a graph
# Author links open overlay panel by Richard Nowakowski, Peter Winkler](https://www.sciencedirect.com/science/article/pii/0012365X83901607)
#
# * [The capture time of a graph - ScienceDirect](https://www.sciencedirect.com/science/article/pii/S0012365X08002173)
#
# * [Cops and Robbers ordinals of cop-win trees - ScienceDirect](https://www.sciencedirect.com/science/article/pii/S0012365X16304307)
#
# * [Characterizations of k-copwin graphs - ScienceDirect](https://www.sciencedirect.com/science/article/pii/S0012365X12000064)
#
# <u>Vidéo :<u>
#
# * [Des intelligences artificielles jouent à cache-cache et crack le jeu !](https://www.youtube.com/watch?v=tfGJtIdslfs)
#
# * [J'ai codé un robot pour ATOMISER Crossy Road](https://www.youtube.com/watch?v=71UbDN4csas)
#
# * [The Cops and Robbers Theorem | Infinite Series](https://www.youtube.com/watch?v=9mJEu-j1KT0)
